# %% [markdown]
# # 모델 3: XGBoost
#
# 이 노트북은 `ModelTrainer`를 활용하여 표준화된 데이터 파이프라인 상에서 XGBoost 모델을 학습하고 평가합니다.

# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt
from xgboost import XGBClassifier, plot_importance
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import roc_auc_score

# src 폴더 경로 추가 및 ModelTrainer 임포트
sys.path.append(os.path.abspath('../src'))
from model_trainer import ModelTrainer

# %% [markdown]
# ## 1. 데이터 로드 및 준비

# %%
trainer = ModelTrainer()
(X_train, y_train), (X_val, y_val), (X_test, y_test) = trainer.get_prepared_data()

# %% [markdown]
# ## 2. XGBoost 학습 및 교차 검증

# %%
tscv = TimeSeriesSplit(n_splits=5)
cv_scores = []

for tr_idx, te_idx in tscv.split(X_train):

# %% [markdown]
# ## 3. 성능 평가 및 시각화

# %%
trainer.evaluate_model(final_model, X_test, y_test, "XGBoost")
trainer.save_model(final_model, "model3_xgboost")

# ROC-AUC 분석
y_prob = final_model.predict_proba(X_test)[:, 1]
print(f"ROC-AUC Score: {roc_auc_score(y_test, y_prob):.4f}")

# 변수 중요도 플롯
plt.figure(figsize=(10, 8))
plot_importance(final_model, max_num_features=15)
plt.show()
