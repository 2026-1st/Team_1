# %% [markdown]
# # 모델 2: 랜덤 포레스트 (Random Forest)
#
# 이 노트북은 `ModelTrainer`를 활용하여 표준화된 데이터 파이프라인 상에서 랜덤 포레스트 모델을 학습하고 평가합니다.

# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import TimeSeriesSplit

# src 폴더 경로 추가 및 ModelTrainer 임포트
sys.path.append(os.path.abspath('../src'))
from model_trainer import ModelTrainer

# %% [markdown]
# ## 1. 데이터 로드 및 준비

# %%
trainer = ModelTrainer()
(X_train, y_train), (X_val, y_val), (X_test, y_test) = trainer.get_prepared_data()

# %% [markdown]
# ## 2. 랜덤 포레스트 학습 및 교차 검증

# %%
tscv = TimeSeriesSplit(n_splits=5)
cv_scores = []

for tr_idx, te_idx in tscv.split(X_train):

# %% [markdown]
# ## 3. 모델 평가 및 변수 중요도

# %%
trainer.evaluate_model(final_model, X_test, y_test, "Random Forest")
trainer.save_model(final_model, "model2_random_forest")

# 변수 중요도 시각화
importances = final_model.feature_importances_
indices = np.argsort(importances)[::-1]
features = trainer.features

plt.figure(figsize=(10, 6))
sns.barplot(x=importances[indices], y=np.array(features)[indices])
plt.title("Feature Importances - Random Forest")
plt.show()
